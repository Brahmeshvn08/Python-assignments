# %% [markdown]
# <a href="https://colab.research.google.com/github/Brahmeshvn08/Python-assignments/blob/main/Electrical_Consumption.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***DATA MANIPULATION AND ANALYSIS USING PANDAS***

# %% [markdown]
# **Overview**
#
# *   **Why Use Pandas?**
#
#   It simplifies data manipulation and analysis tasks that would be cumbersome with raw Python structures or NumPy arrays alone.
#
#   PANDAS is a famous library of python which helps us in giving out the accurate insights of the data.

# %% [markdown]
# **Data I/O and Basic Exploration**
# - **Reading Data:**
#   Use `pd.read_csv()` to load data from a CSV file.
# - **Previewing Data:**
#   Use `df.head()` to view the first few rows.
#
# *Make sure you have the file* `sample_data.csv` *in your working directory.*

# %%
#Importing of pandas library
import pandas as pd
pd.read_csv('/content/electrical_consumption.csv')
# Out:
#      Customer_ID Region  Consumption_kWh  Billing_Amount  Power_Factor  \
# 0           1001   East           479.26           66.34          0.99
# 1           1002   West           414.44           63.54          0.99
# 2           1003  North           323.81           31.79          0.97
# 3           1004   East           525.52           53.89           NaN
# 4           1005   East           473.89           56.61          0.95
# ..           ...    ...              ...             ...           ...
# 995         1996  North           467.29           64.46          0.95
# 996         1997  North           447.80           70.41          0.99
# 997         1998   West           385.40           90.59          0.99
# 998         1999   West           351.91           98.65          0.95
# 999         2000   East           545.33           58.53          0.98
#
#     Meter_Status  Peak_Hours_Consumption
# 0         Active                  219.86
# ...

# %%
df=pd.read_csv('/content/electrical_consumption.csv') #Assigning Dataset to a variable df
df.head() #Displays the first few rows of the DataFrame
# Out:
#    Customer_ID Region  Consumption_kWh  Billing_Amount  Power_Factor  \
# 0         1001   East           479.26           66.34          0.99
# 1         1002   West           414.44           63.54          0.99
# 2         1003  North           323.81           31.79          0.97
# 3         1004   East           525.52           53.89           NaN
# 4         1005   East           473.89           56.61          0.95
#
#   Meter_Status  Peak_Hours_Consumption
# 0       Active                  219.86
# 1     Inactive                  202.74
# 2          NaN                  157.64
# 3       Active                  101.29
# 4     Inactive                  199.25

# %%
df.tail() #Displays the last few rows of the DataFrame
# Out:
#      Customer_ID Region  Consumption_kWh  Billing_Amount  Power_Factor  \
# 995         1996  North           467.29           64.46          0.95
# 996         1997  North           447.80           70.41          0.99
# 997         1998   West           385.40           90.59          0.99
# 998         1999   West           351.91           98.65          0.95
# 999         2000   East           545.33           58.53          0.98
#
#     Meter_Status  Peak_Hours_Consumption
# 995     Inactive                  166.76
# 996     Inactive                  215.86
# 997       Active                  277.80
# 998       Active                  213.86
# 999       Active                  226.34

# %%
df.head(300) #views first 300 rows
# Out:
#      Customer_ID Region  Consumption_kWh  Billing_Amount  Power_Factor  \
# 0           1001   East           479.26           66.34          0.99
# 1           1002   West           414.44           63.54          0.99
# 2           1003  North           323.81           31.79          0.97
# 3           1004   East           525.52           53.89           NaN
# 4           1005   East           473.89           56.61          0.95
# ..           ...    ...              ...             ...           ...
# 295         1296   West           548.85           35.94          0.97
# 296         1297  South           572.85           80.14          0.94
# 297         1298   East           426.05           35.05          0.98
# 298         1299  North           478.66           34.99           NaN
# 299         1300   West           569.00           30.85          0.95
#
#     Meter_Status  Peak_Hours_Consumption
# 0         Active                  219.86
# ...

# %%
df.tail(300) #views last 300 rows
# Out:
#      Customer_ID Region  Consumption_kWh  Billing_Amount  Power_Factor  \
# 700         1701  South           503.31           98.38          0.97
# 701         1702   West           209.83           37.75          0.97
# 702         1703  North           208.85           59.58          0.95
# 703         1704   West           329.44           32.94          0.99
# 704         1705  North           395.46           81.79          0.98
# ..           ...    ...              ...             ...           ...
# 995         1996  North           467.29           64.46          0.95
# 996         1997  North           447.80           70.41          0.99
# 997         1998   West           385.40           90.59          0.99
# 998         1999   West           351.91           98.65          0.95
# 999         2000   East           545.33           58.53          0.98
#
#     Meter_Status  Peak_Hours_Consumption
# 700     Inactive                  160.90
# ...

# %%
df2=df.head(300) #Assigning 300 rows to a new Dataframe 2 (df2) variable
df2.head() #Displays the first few rows of Dataframe 2
# Out:
#    Customer_ID Region  Consumption_kWh  Billing_Amount  Power_Factor  \
# 0         1001   East           479.26           66.34          0.99
# 1         1002   West           414.44           63.54          0.99
# 2         1003  North           323.81           31.79          0.97
# 3         1004   East           525.52           53.89           NaN
# 4         1005   East           473.89           56.61          0.95
#
#   Meter_Status  Peak_Hours_Consumption
# 0       Active                  219.86
# 1     Inactive                  202.74
# 2          NaN                  157.64
# 3       Active                  101.29
# 4     Inactive                  199.25

# %%
df2.info() #Gets a concise summary of the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer_ID             300 non-null    int64
#  1   Region                  300 non-null    object
#  2   Consumption_kWh         300 non-null    float64
#  3   Billing_Amount          300 non-null    float64
#  4   Power_Factor            271 non-null    float64
#  5   Meter_Status            272 non-null    object
#  6   Peak_Hours_Consumption  300 non-null    float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 16.5+ KB

# %%
df2.describe() #Generates descriptive statistics
# Out:
#        Customer_ID  Consumption_kWh  Billing_Amount  Power_Factor  \
# count   300.000000       300.000000      300.000000    271.000000
# mean   1150.500000       397.712467       64.189833      0.964428
# std      86.746758       114.164009       20.283401      0.017959
# min    1001.000000       205.820000       30.530000      0.940000
# 25%    1075.750000       296.735000       46.330000      0.950000
# 50%    1150.500000       398.215000       64.475000      0.960000
# 75%    1225.250000       499.002500       80.812500      0.980000
# max    1300.000000       599.890000       99.770000      0.990000
#
#        Peak_Hours_Consumption
# count              300.000000
# mean               200.324733
# std                 57.937185
# min                100.050000
# 25%                149.932500
# 50%                199.630000
# 75%                251.085000
# max                299.390000

# %%
df2.shape #Gets the dimensions of the DataFrame
# Out:
# (300, 7)

# %%
df2.columns #Lists the column names
# Out:
# Index(['Customer_ID', 'Region', 'Consumption_kWh', 'Billing_Amount',
#        'Power_Factor', 'Meter_Status', 'Peak_Hours_Consumption'],
#       dtype='object')

# %%
df2.dtypes #Display data types of each column
# Out:
# Customer_ID                 int64
# Region                     object
# Consumption_kWh           float64
# Billing_Amount            float64
# Power_Factor              float64
# Meter_Status               object
# Peak_Hours_Consumption    float64
# dtype: object

# %%
df2['Meter_Status'] #Selects a single column
# Out:
# 0        Active
# 1      Inactive
# 2           NaN
# 3        Active
# 4      Inactive
#          ...
# 295    Inactive
# 296    Inactive
# 297      Active
# 298      Active
# 299    Inactive
# Name: Meter_Status, Length: 300, dtype: object

# %%
df2[['Consumption_kWh','Billing_Amount','Meter_Status']] #Selects multiple columns
# Out:
#      Consumption_kWh  Billing_Amount Meter_Status
# 0             479.26           66.34       Active
# 1             414.44           63.54     Inactive
# 2             323.81           31.79          NaN
# 3             525.52           53.89       Active
# 4             473.89           56.61     Inactive
# ..               ...             ...          ...
# 295           548.85           35.94     Inactive
# 296           572.85           80.14     Inactive
# 297           426.05           35.05       Active
# 298           478.66           34.99       Active
# 299           569.00           30.85     Inactive
#
# [300 rows x 3 columns]

# %%
df2.iloc[3:9] #Selects data by integer-based indexing
# Out:
#    Customer_ID Region  Consumption_kWh  Billing_Amount  Power_Factor  \
# 3         1004   East           525.52           53.89           NaN
# 4         1005   East           473.89           56.61          0.95
# 5         1006   West           265.05           57.92          0.94
# 6         1007  North           564.37           70.61          0.99
# 7         1008  North           529.01           67.35          0.96
# 8         1009   East           579.92           72.55          0.99
#
#   Meter_Status  Peak_Hours_Consumption
# 3       Active                  101.29
# 4     Inactive                  199.25
# 5     Inactive                  157.13
# 6          NaN                  246.92
# 7     Inactive                  104.79
# 8     Inactive                  216.97

# %%
df2.loc[3:9,'Consumption_kWh':'Power_Factor'] #Selects data by label-based indexing
# Out:
#    Consumption_kWh  Billing_Amount  Power_Factor
# 3           525.52           53.89           NaN
# 4           473.89           56.61          0.95
# 5           265.05           57.92          0.94
# 6           564.37           70.61          0.99
# 7           529.01           67.35          0.96
# 8           579.92           72.55          0.99
# 9           490.29           83.54          0.99

# %%
df2[df2['Billing_Amount']>70] #Filters rows based on a condition
# Out:
#      Customer_ID Region  Consumption_kWh  Billing_Amount  Power_Factor  \
# 6           1007  North           564.37           70.61          0.99
# 8           1009   East           579.92           72.55          0.99
# 9           1010  South           490.29           83.54          0.99
# 10          1011   East           445.37           86.91          0.94
# 11          1012   East           367.30           80.27          0.99
# ..           ...    ...              ...             ...           ...
# 286         1287  North           433.36           74.57           NaN
# 287         1288  North           360.34           72.98          0.95
# 291         1292   East           434.49           81.62           NaN
# 293         1294  South           444.58           77.62          0.95
# 296         1297  South           572.85           80.14          0.94
#
#     Meter_Status  Peak_Hours_Consumption
# 6            NaN                  246.92
# ...

# %%
df2.groupby('Customer_ID')[['Consumption_kWh','Billing_Amount',]].mean() #Groups data for aggregation operations
# Out:
#              Consumption_kWh  Billing_Amount  Power_Factor
# Customer_ID
# 1001                  479.26           66.34          0.99
# 1002                  414.44           63.54          0.99
# 1003                  323.81           31.79          0.97
# 1004                  525.52           53.89           NaN
# 1005                  473.89           56.61          0.95
# ...                      ...             ...           ...
# 1296                  548.85           35.94          0.97
# 1297                  572.85           80.14          0.94
# 1298                  426.05           35.05          0.98
# 1299                  478.66           34.99           NaN
# 1300                  569.00           30.85          0.95
#
# [300 rows x 3 columns]

# %%
df2.isnull().sum() #Detects the total no.of missing values from each column
# Out:
# Customer_ID                0
# Region                     0
# Consumption_kWh            0
# Billing_Amount             0
# Power_Factor              29
# Meter_Status              28
# Peak_Hours_Consumption     0
# dtype: int64

# %%
df2.dropna() #Remove rows with missing values
# Out:
#      Customer_ID Region  Consumption_kWh  Billing_Amount  Power_Factor  \
# 0           1001   East           479.26           66.34          0.99
# 1           1002   West           414.44           63.54          0.99
# 4           1005   East           473.89           56.61          0.95
# 5           1006   West           265.05           57.92          0.94
# 7           1008  North           529.01           67.35          0.96
# ..           ...    ...              ...             ...           ...
# 294         1295  South           207.24           32.92          0.96
# 295         1296   West           548.85           35.94          0.97
# 296         1297  South           572.85           80.14          0.94
# 297         1298   East           426.05           35.05          0.98
# 299         1300   West           569.00           30.85          0.95
#
#     Meter_Status  Peak_Hours_Consumption
# 0         Active                  219.86
# ...

# %%
df2.duplicated() #Checks for duplicate rows
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 295    False
# 296    False
# 297    False
# 298    False
# 299    False
# Length: 300, dtype: bool

# %%
df2.sort_values(['Billing_Amount','Power_Factor']) #Sort the DataFrame by one or more columns
# Out:
#      Customer_ID Region  Consumption_kWh  Billing_Amount  Power_Factor  \
# 15          1016  North           210.55           30.53           NaN
# 243         1244  North           401.09           30.77          0.94
# 252         1253   West           451.08           30.85          0.95
# 299         1300   West           569.00           30.85          0.95
# 13          1014   East           546.43           31.28          0.97
# ..           ...    ...              ...             ...           ...
# 164         1165  South           240.71           99.45          0.98
# 138         1139   East           307.70           99.47           NaN
# 116         1117  North           224.43           99.59          0.96
# 215         1216  North           571.81           99.64          0.95
# 227         1228  South           518.11           99.77          0.95
#
#     Meter_Status  Peak_Hours_Consumption
# 15           NaN                  181.47
# ...

# %%
df2['Power_Factor'].fillna(0.96,inplace=True) #Fill missing values with a specified value
# Out:
# <ipython-input-6-35f13a55a306>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['Power_Factor'].fillna(0.96,inplace=True) #Fill missing values with a specified value
# <ipython-input-6-35f13a55a306>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df2.head()
# Out:
#    Customer_ID Region  Consumption_kWh  Billing_Amount  Power_Factor  \
# 0         1001   East           479.26           66.34          0.99
# 1         1002   West           414.44           63.54          0.99
# 2         1003  North           323.81           31.79          0.97
# 3         1004   East           525.52           53.89          0.96
# 4         1005   East           473.89           56.61          0.95
#
#   Meter_Status  Peak_Hours_Consumption
# 0       Active                  219.86
# 1     Inactive                  202.74
# 2          NaN                  157.64
# 3       Active                  101.29
# 4     Inactive                  199.25

# %%
df2['Load_Factor']=round(df2['Consumption_kWh']/df2['Peak_Hours_Consumption'],2) #Add a new column to the DataFrame
# Out:
# <ipython-input-8-d49646e0d508>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Load_Factor']=round(df2['Consumption_kWh']/df2['Peak_Hours_Consumption'],2) #Add a new column to the DataFrame

# %%
df2.head()
# Out:
#    Customer_ID Region  Consumption_kWh  Billing_Amount  Power_Factor  \
# 0         1001   East           479.26           66.34          0.99
# 1         1002   West           414.44           63.54          0.99
# 2         1003  North           323.81           31.79          0.97
# 3         1004   East           525.52           53.89          0.96
# 4         1005   East           473.89           56.61          0.95
#
#   Meter_Status  Peak_Hours_Consumption  Load_Factor
# 0       Active                  219.86         2.18
# 1     Inactive                  202.74         2.04
# 2          NaN                  157.64         2.05
# 3       Active                  101.29         5.19
# 4     Inactive                  199.25         2.38

# %%
df2=df2.rename(columns={'Consumption_kWh':'Total_Consumption_kWh'}) #Rename DataFrame columns

# %%
df2.head()
# Out:
#    Customer_ID Region  Total_Consumption_kWh  Billing_Amount  Power_Factor  \
# 0         1001   East                 479.26           66.34          0.99
# 1         1002   West                 414.44           63.54          0.99
# 2         1003  North                 323.81           31.79          0.97
# 3         1004   East                 525.52           53.89          0.96
# 4         1005   East                 473.89           56.61          0.95
#
#   Meter_Status  Peak_Hours_Consumption  Load_Factor
# 0       Active                  219.86         2.18
# 1     Inactive                  202.74         2.04
# 2          NaN                  157.64         2.05
# 3       Active                  101.29         5.19
# 4     Inactive                  199.25         2.38

# %%
df2=df2.set_index('Customer_ID') #Set a column as the index

# %%
df2.head()
# Out:
#             Region  Total_Consumption_kWh  Billing_Amount  Power_Factor  \
# Customer_ID
# 1001          East                 479.26           66.34          0.99
# 1002          West                 414.44           63.54          0.99
# 1003         North                 323.81           31.79          0.97
# 1004          East                 525.52           53.89          0.96
# 1005          East                 473.89           56.61          0.95
#
#             Meter_Status  Peak_Hours_Consumption  Load_Factor
# Customer_ID
# 1001              Active                  219.86         2.18
# 1002            Inactive                  202.74         2.04
# 1003                 NaN                  157.64         2.05
# 1004              Active                  101.29         5.19
# 1005            Inactive                  199.25         2.38

# %%
df2.reset_index() #Reset the DataFrame index
# Out:
#      Customer_ID Region  Total_Consumption_kWh  Billing_Amount  Power_Factor  \
# 0           1001   East                 479.26           66.34          0.99
# 1           1002   West                 414.44           63.54          0.99
# 2           1003  North                 323.81           31.79          0.97
# 3           1004   East                 525.52           53.89          0.96
# 4           1005   East                 473.89           56.61          0.95
# ..           ...    ...                    ...             ...           ...
# 295         1296   West                 548.85           35.94          0.97
# 296         1297  South                 572.85           80.14          0.94
# 297         1298   East                 426.05           35.05          0.98
# 298         1299  North                 478.66           34.99          0.96
# 299         1300   West                 569.00           30.85          0.95
#
# ...

# %%
df2.to_csv() #Write the DataFrame to a CSV file
# Out:
# 'Customer_ID,Region,Total_Consumption_kWh,Billing_Amount,Power_Factor,Meter_Status,Peak_Hours_Consumption,Load_Factor\n1001,East,479.26,66.34,0.99,Active,219.86,2.18\n1002,West,414.44,63.54,0.99,Inactive,202.74,2.04\n1003,North,323.81,31.79,0.97,,157.64,2.05\n1004,East,525.52,53.89,0.96,Active,101.29,5.19\n1005,East,473.89,56.61,0.95,Inactive,199.25,2.38\n1006,West,265.05,57.92,0.94,Inactive,157.13,1.69\n1007,North,564.37,70.61,0.99,,246.92,2.29\n1008,North,529.01,67.35,0.96,Inactive,104.79,5.05\n1009,East,579.92,72.55,0.99,Inactive,216.97,2.67\n1010,South,490.29,83.54,0.99,Active,288.29,1.7\n1011,East,445.37,86.91,0.94,Active,134.88,3.3\n1012,East,367.3,80.27,0.99,Active,194.33,1.89\n1013,East,573.09,96.89,0.96,,118.28,4.85\n1014,East,546.43,31.28,0.97,Inactive,225.14,2.43\n1015,West,218.09,43.7,0.98,Inactive,210.11,1.04\n1016,North,210.55,30.53,0.96,,181.47,1.16\n1017,West,350.59,75.32,0.94,Active,204.28,1.72\n1018,West,524.22,92.86,0.97,Active,279.31,1.88\n1019,West,594.91,47.04,0
# ...

# %% [markdown]
# # ***MATPLOTLIB***

# %% [markdown]
# **Overview**
# - **Purpose:**
#   Matplotlib is the go-to library for creating visualizations in Python.
# - **Flexibility:**
#   Offers extensive customization options for plot styling, axes, labels, legends, and more.

# %% [markdown]
# **Basic Plotting**
#
#   Line Plot: Salary vs. Age
#
# *   Line Plot: Salary vs. Age
# *   Visualize the relationship between Age and Salary using a line plot.

# %%
df2=df2.head(5)

# %%
df2.head()
# Out:
#             Region  Total_Consumption_kWh  Billing_Amount  Power_Factor  \
# Customer_ID
# 1001          East                 479.26           66.34          0.99
# 1002          West                 414.44           63.54          0.99
# 1003         North                 323.81           31.79          0.97
# 1004          East                 525.52           53.89          0.96
# 1005          East                 473.89           56.61          0.95
#
#             Meter_Status  Peak_Hours_Consumption  Load_Factor
# Customer_ID
# 1001              Active                  219.86         2.18
# 1002            Inactive                  202.74         2.04
# 1003                 NaN                  157.64         2.05
# 1004              Active                  101.29         5.19
# 1005            Inactive                  199.25         2.38

# %%
import matplotlib.pyplot as plt

# Line Plot: Peak_Hours_Consumption vs. Total_Consumption_kWh using the DataFrame (df)
plt.figure(figsize=(6, 4))
plt.plot(df2['Peak_Hours_Consumption'], df2['Total_Consumption_kWh'], marker='o', linestyle='-')
plt.title('Peak_Hours_Consumption vs. Total_Consumption_kWh')
plt.xlabel('Peak_Hours_Consumption')
plt.ylabel('Total_Consumption_kWh')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Bar Chart:
# Use a bar chart to visualize aggregated data.

# %%
# Bar Chart: Average of Peak_Hours_Consumption across different meter statuses.
df2.plot(kind='bar')
# Out:
# <Axes: xlabel='Customer_ID'>

# %% [markdown]
# #### Histogram: Age Distribution
# Display the distribution of ages in the dataset.

# %%
df2['Load_Factor'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
